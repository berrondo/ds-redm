# %%
from notebook_importer import *

from base import df
from sequencias import dh, dt2

import pandas as pd

# %%
df.head()
# Out:
#    demanda             criacao                  em  \
# 0       38 2013-03-06 11:47:35 2013-06-04 16:20:21
# 1       38 2013-03-06 11:47:35 2013-06-13 16:54:26
# 2       38 2013-03-06 11:47:35 2013-06-14 09:59:39
# 3       38 2013-03-06 11:47:35 2014-07-29 15:51:40
# 4       38 2013-03-06 11:47:35 2014-07-29 15:51:54
#
#                                                   de  \
# 0                                       DESCONHECIDO
# 1                           Estimar pontos de função
# 2         Elaborar parecer: desenvolver ou adquirir?
# 3  Considerar decisão da DISIS: ratificar ou reti...
# 4                      Atualizar registro da demanda
#
#                                                 para        acum_tempo  \
# 0                           Estimar pontos de função  90 days 04:32:46
# 1         Elaborar parecer: desenvolver ou adquirir?  99 days 05:06:51
# 2  Considerar decisão da DISIS: ratificar ou reti...  99 days 22:12:04
# ...

# %%
dh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24738 entries, 0 to 24737
# Data columns (total 2 columns):
# demanda      24738 non-null int64
# sequencia    24738 non-null object
# dtypes: int64(1), object(1)
# memory usage: 386.7+ KB

# %%
dt2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 598 entries, 0 to 597
# Data columns (total 4 columns):
# sequencia      598 non-null object
# demanda        598 non-null int64
# sequencia.1    598 non-null int64
# tipo           598 non-null object
# dtypes: int64(2), object(2)
# memory usage: 18.8+ KB

# %%
dm = pd.merge(dh, dt2, on='sequencia')
dm
# Out:
#        demanda_x                                          sequencia  \
# 0             38  (('DESCONHECIDO', 'Estimar pontos de função'),...
# 1             73  (('DESCONHECIDO', 'Estimar pontos de função'),...
# 2             74  (('DESCONHECIDO', 'Estimar pontos de função'),...
# 3             77  (('Realizar implementação', 'Elaborar procedim...
# 4             78  (('Realizar implementação', 'Elaborar procedim...
# ...          ...                                                ...
# 24733      25359  (('Novo', 'Realizar orçamento'), ('Realizar or...
# 24734      25383  (('Novo', 'Realizar orçamento'), ('Realizar or...
# 24735      25386  (('Novo', 'Realizar orçamento'), ('Realizar or...
# 24736      25402  (('Novo', 'Desenvolver internamente'), ('Desen...
# 24737      25466  (('Novo', 'Realizar orçamento'), ('Realizar or...
#
#        demanda_y  sequencia.1     tipo
# 0              1            1  interna
# 1              1            1  interna
# ...

# %%
d9 = pd.merge(df, dm[['demanda_x', 'tipo']], left_on='demanda', right_on='demanda_x')

# %%
d9
# Out:
#        demanda             criacao                  em  \
# 0           38 2013-03-06 11:47:35 2013-06-04 16:20:21
# 1           38 2013-03-06 11:47:35 2013-06-13 16:54:26
# 2           38 2013-03-06 11:47:35 2013-06-14 09:59:39
# 3           38 2013-03-06 11:47:35 2014-07-29 15:51:40
# 4           38 2013-03-06 11:47:35 2014-07-29 15:51:54
# ...        ...                 ...                 ...
# 80401    25504 2020-01-24 16:08:19 2020-01-24 17:35:26
# 80402    25504 2020-01-24 16:08:19 2020-01-24 17:40:14
# 80403    25507 2020-01-27 07:56:36 2020-01-27 09:52:40
# 80404    25509 2020-01-27 11:05:30 2020-01-27 11:43:34
# 80405    25509 2020-01-27 11:05:30 2020-01-27 11:48:00
#
#                                                       de  \
# 0                                           DESCONHECIDO
# 1                               Estimar pontos de função
# 2             Elaborar parecer: desenvolver ou adquirir?
# 3      Considerar decisão da DISIS: ratificar ou reti...
# ...
